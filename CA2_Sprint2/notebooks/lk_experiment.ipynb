# %%
import mlflow
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import root_mean_squared_error, r2_score

# %% [markdown]
# ### Run this code first
# mlflow server --backend-store-uri sqlite:///mlflow.db --artifacts-destination ./artifacts --port 5000

# %%
mlflow_url = "http://localhost:5000" # Make sure this server is running following practical instructions.
mlflow.set_tracking_uri(mlflow_url)
mlflow.set_experiment("lk_experiment")
# Out:
# 2026/01/17 22:24:38 INFO mlflow.tracking.fluent: Experiment with name 'lk_experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1768659878814, experiment_id='1', last_update_time=1768659878814, lifecycle_stage='active', name='lk_experiment', tags={}>
